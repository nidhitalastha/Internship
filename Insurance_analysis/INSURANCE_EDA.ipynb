# %% [markdown]
# # Analysis On Health Insurance

# %% [markdown]
# ### Importing the required libraries for the analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Reading the data set

# %%
df = pd.read_csv("insurance.csv")

df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ### Identifying the features or variables and their data types and the structure of the data set

# %%
df.info()

print(df.describe())

df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# ...

# %% [markdown]
# ### Univariate analysis on numerical variables

# %%
plt.figure(figsize = (20,10))
ax1 = sns.boxplot(x = "age", data = df)
plt.grid(True)
plt.xlabel("Age", fontsize = 20)
plt.ylabel("Count", fontsize = 20)
plt.show()

plt.figure(figsize = (20,10))
plt.grid(True)
ax1 = sns.boxplot(x = "bmi", data = df)
plt.xlabel("BMI", fontsize = 20)
plt.ylabel("Count", fontsize = 20)
plt.show()

plt.figure(figsize = (20,10))
plt.grid(True)
ax1 = sns.boxplot(x = "children", data = df)
plt.xlabel("Children", fontsize = 20)
plt.ylabel("Count", fontsize = 20)
plt.show()

plt.figure(figsize = (20,10))
plt.grid(True)
ax1 = sns.boxplot(x = "charges", data = df)
plt.xlabel("Charges", fontsize = 20)
plt.ylabel("Count", fontsize = 20)
plt.show()

# %% [markdown]
# The above output gives the information about the numerical variables in the data set graphically. We have chosen the boxplot to represent the numerical data as the boxplot gives the minimum , 1st quartile(25%) , median(50%) , 3rd quartile(75%) and maximum values of that column or variable
#
# Age : As we can see 50% of the insured are in the age group of 38 to 40 where as the minimum and maximum age as per the data are 18 and 62-62 respectively. As a whole 25% to 75% insured are between the age group of 27 to 52 .
#
# BMI : The ideal BMI value lies between 18.5 and 24.9 . According to the the data set 50% of the insured lie around the value of 31 to 32 which is not ideal . 25% to 75% of the insured lie around the values 26 to 34 . There are a handful of insured whose BMI is above the value 46 .
#
# Children : 25% of the insured do not have a child where 50% of them have one child and 75% of them have 2 children . Rest of the insured have 3 , 4 , or 5 children.
#
# Charges : 25% of the charges lie around 5000 dollars where as 50% and 75% of them lie around 10000 and 15000 dollars respectively . The rest either lie around 1000 to 5000 dollars and 15000 to 35000 dollars . There are very less number of insured whose charges lie above 35000 dollars which might be due to their known medical conditions .

# %% [markdown]
# ### Univariate analysis on categorical variables

# %%
params = {'axes.titlesize':'25',
          'xtick.labelsize':'18',
          'ytick.labelsize':'18'}
plt.rcParams.update(params)
plt.figure(figsize = (8,8))
ax = sns.countplot(x = "smoker", data = df)
plt.grid(True)
plt.xlabel("Smoker", fontsize = 25)
plt.ylabel("Count", fontsize = 25)
plt.show()

params = {'axes.titlesize':'25',
          'xtick.labelsize':'18',
          'ytick.labelsize':'18'}
plt.rcParams.update(params)
plt.figure(figsize = (8,8))
ax = sns.countplot(x = "region", data = df)
plt.grid(True)
plt.xlabel("Region", fontsize = 25)
plt.ylabel("Count", fontsize = 25)
plt.show()

params = {'axes.titlesize':'25',
          'xtick.labelsize':'18',
          'ytick.labelsize':'18'}
plt.rcParams.update(params)
plt.figure(figsize = (8,8))
ax = sns.countplot(x = "sex", data = df)
plt.grid(True)
plt.xlabel("Sex", fontsize = 25)
plt.ylabel("Count", fontsize = 25)
plt.show()

# %% [markdown]
# As we can see in the above graphical representation of the categorical data we know that :
#
# Smoker : More than 50% of the insure are non smoker which implies that they are in a better health conditions when compared to those who smoke.
#
# Region : The number of insured living in different regions of US is almost the same according the graph but there are slightly more number of insured living in the southeast region specifically that can be noticed.
#
# Sex : The number of male insured are slightly more than number of female in the given data set.

# %% [markdown]
# ### Bivariate analysis with the categorical variables

# %%
params = {'axes.titlesize':'25',
          'xtick.labelsize':'18',
          'ytick.labelsize':'18'}
plt.rcParams.update(params)
plt.figure(figsize = (20,10))
ax = sns.violinplot(x="sex", y="charges", data=df)
plt.grid(True)
plt.xlabel("Sex", fontsize = 25)
plt.ylabel("Charges", fontsize = 25)
plt.show()


params = {'axes.titlesize':'25',
          'xtick.labelsize':'18',
          'ytick.labelsize':'18'}
plt.rcParams.update(params)
plt.figure(figsize = (20,10))
ax = sns.violinplot(x="smoker", y="charges", data=df)
plt.grid(True)
plt.xlabel("Smoker", fontsize = 25)
plt.ylabel("Charges", fontsize = 25)
plt.show()


params = {'axes.titlesize':'25',
          'xtick.labelsize':'18',
          'ytick.labelsize':'18'}
plt.rcParams.update(params)
plt.figure(figsize = (20,10))
ax = sns.violinplot(x="region", y="charges", data=df)
plt.grid(True)
plt.xlabel("Region", fontsize = 25)
plt.ylabel("Charges", fontsize = 25)
plt.show()

# %% [markdown]
# Bivariate analysis is the analysis done between the other variables in the data set and the target variable . In the above we have used the violin plot for representation . It gives us the details that a box plot gives but doen not display the outliers separately . The wider the width of the violin the higher frequency of the corresponding value and the narrower the width lower the frequency of the corresponding value .
#
# Sex v/s Charges : Charges for 75% of the female insured lie around 10000 dollars . On the other hand the charges lie around 20000 dollars for upto 75% of male insured . As the value of charges increase the width of the violin narrows and then again widens around the value 30000 to 50000 for both male and female which implies there are considerate amount of the insured whose charges are high due to their health conditions or their age or it might also be that they are smokers and are prone to more diseases . The number of male insured is more compred to that of female in the region of high charges as more men travel around for work when compared to women and hence they can be the ones prone to more diseases.
#
# Smoker v/s Charges : The charges start from 10000 dollars for that of smoker and the charges lie within 10000 dollars for most non smokers which implies smoking is an important feature for an insured to decide on the charges by the company. As we can see the width of the violin varies as the charges increases which can be due to the age of the insured and the number of family members or children . Most of the number of charges of that of the smokers lie between 20000 to 40000 dollars where as for non smokers it lies between 5000 to 12000 dollars. The width the of the violin of the smokers narrows from around 60000  and ends at around 72000 dollars, as for that of non smokers the violin narrows from 30000 and ends at around 40000 dollars.
#
# Region v/s Charges : 50% of the insured living in different regions of the US correspond to the charges around 10000 dollars. The width of the violin start getting narrow and then again widens around 30000 to 50000 for southeast, southwest and northeast regions mostly . The charges are higher for southeast region when compared to the other regions, this might be due to higher cost of living in that region .

# %% [markdown]
# ### Bivariate analysis with the numerical variables

# %%
fig = plt.figure(figsize = (20,12))
params = {'axes.titlesize':'25',
          'xtick.labelsize':'25',
          'ytick.labelsize':'25'}
plt.rcParams.update(params)
ax = fig.add_axes([0,0,1,1])
ax.bar(df["age"], df["charges"])
plt.ylabel("Charges", fontsize = 30)
plt.xlabel("Age", fontsize = 30)
plt.grid(True)
plt.show()

fig = plt.figure(figsize = (20,12))
params = {'axes.titlesize':'25',
          'xtick.labelsize':'25',
          'ytick.labelsize':'25'}
plt.rcParams.update(params)
ax = fig.add_axes([0,0,1,1])
ax.bar(df["children"], df["charges"])
plt.ylabel("Charges", fontsize = 30)
plt.xlabel("Children", fontsize = 30)
plt.grid(True)
plt.show()

fig = plt.figure(figsize = (20,12))
params = {'axes.titlesize':'25',
          'xtick.labelsize':'25',
          'ytick.labelsize':'25'}
plt.rcParams.update(params)
ax = fig.add_axes([0,0,1,1])
ax.bar(df["bmi"], df["charges"])
plt.ylabel("Charges", fontsize = 30)
plt.xlabel("BMI", fontsize = 30)
plt.grid(True)
plt.show()

# %% [markdown]
# Age v/s Charges : The charges increases as the the age does as per the graph . This might be because the elderly insured are more prone to diseases or health issues when compare to the younger ones . And it also depends on if the individual is a smoker or non smoker .
#
#
# Children v/s Charges : The charges for an individual with no kids is high when compared to that of the other individuals with 1 or 5 kids. This might be because the charges per individual decreases when the number of members in the family is more .
#
#
# BMI v/s Charges : The charges increase as the BMI increases upto 32 and then the BMI values correspond to almost the same charges and then decreases and then again increases. As we can see the charges dont have are not certain corresponding to the BMI which implies BMI might not be so good variable to predict the charges . It might be useful when combined with another variable to predict the charges .

# %% [markdown]
# ### Multivariate analysis

# %%
params = {'axes.titlesize':'25',
          'xtick.labelsize':'25',
          'ytick.labelsize':'25'}
plt.rcParams.update(params)
sns.lmplot(x = "bmi", y = "charges", data = df, hue = "smoker", height = 8, aspect = 2)
plt.ylabel("Charges", fontsize = 30)
plt.xlabel("BMI", fontsize = 30)
plt.grid(True)
plt.show()

params = {'axes.titlesize':'25',
          'xtick.labelsize':'25',
          'ytick.labelsize':'25'}
plt.rcParams.update(params)
plt.figure(figsize = (20,10))
sns.lmplot(x = "age", y = "charges", data = df, hue = "smoker", height = 8, aspect = 2)
plt.ylabel("Charges", fontsize = 30)
plt.xlabel("Age", fontsize = 30)
plt.grid(True)
plt.show()



params = {'axes.titlesize':'25',
          'xtick.labelsize':'25',
          'ytick.labelsize':'25'}
plt.rcParams.update(params)
plt.figure(figsize = (20,10))
sns.lmplot(x = "children", y = "charges", data = df, hue = "smoker", height = 8, aspect = 2)
plt.ylabel("Charges", fontsize = 30)
plt.xlabel("Children", fontsize = 30)
plt.grid(True)
plt.show()

# %% [markdown]
# From the above graphs we can note that charges increase as the age increases if the individual is a smoker . Hence smoker is a variable that can be used to predict the charges . And also charges for an individual is higher if he/she is a smoker and their value of BMI is high . We can also notice that the charges are almost constant for an individual with respect to the number of children and whether he/she is a smoker or non smoker which makes the children variable not so important to predict the values of the charges.

# %%
df2 = pd.read_csv("insurance.csv")
df2.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# converting categorical values to numerical values

replace_map = {'sex': {'female': 1, 'male': 2}}
labels = df2['sex'].astype('category').cat.categories.tolist()
replace_map_comp = {'sex' : {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}}
df2.replace(replace_map_comp, inplace=True)

replace_map = {'smoker': {'no': 0, 'yes': 1}}
labels = df2['smoker'].astype('category').cat.categories.tolist()
replace_map_comp = {'smoker' : {k: v for k,v in zip(labels,list(range(0,len(labels)+1)))}}
df2.replace(replace_map_comp, inplace=True)

replace_map = {'region': {'southwest': 1, 'southeast': 2, 'northwest': 3, 'northeast': 4}}
labels = df2['region'].astype('category').cat.categories.tolist()
replace_map_comp = {'region' : {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}}
df2.replace(replace_map_comp, inplace=True)
print(df.tail())
print(df2.head())
print(df2.tail())
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603
#    age  sex     bmi  children  smoker  region      charges
# 0   19    1  27.900         0       1       4  16884.92400
# 1   18    2  33.770         1       0       3   1725.55230
# 2   28    2  33.000         3       0       3   4449.46200
# 3   33    2  22.705         0       0       2  21984.47061
# 4   32    2  28.880         0       0       2   3866.85520
#       age  sex    bmi  children  smoker  region     charges
# 1333   50    2  30.97         3       0       2  10600.5483
# 1334   18    1  31.92         0       0       1   2205.9808
# ...

# %%
df_corr = df2.corr()
params = {'axes.titlesize':'25',
          'xtick.labelsize':'40',
          'ytick.labelsize':'40'}
plt.rcParams.update(params)
plt.figure(figsize = (30, 30))
sns.heatmap(data = df_corr, xticklabels=df_corr.columns.values, 
           yticklabels=df_corr.columns.values, 
           annot=True, annot_kws = {'fontsize' : 35})
plt.show()

# %% [markdown]
# From the above heatmap we can say that charges for an insured is mostly effected based on if the individual is smoker or non smoker than any other variable and is least affected by the region variable .

# %% [markdown]
# ## Linear Regression Model

# %%
from scipy import stats
import statsmodels

data = pd.DataFrame(df2)

# %%
X = data[["age", "sex", "bmi", "children", "smoker", "region"]]
y = data["charges"]

# %%
print(X.head())
print(y.head())
# Out:
#    age  sex     bmi  children  smoker  region
# 0   19    1  27.900         0       1       4
# 1   18    2  33.770         1       0       3
# 2   28    2  33.000         3       0       3
# 3   33    2  22.705         0       0       2
# 4   32    2  28.880         0       0       2
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %%
import statsmodels.api as smf


reg = smf.OLS(y, X).fit()distributed


reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                charges   R-squared (uncentered):                   0.877
# Model:                            OLS   Adj. R-squared (uncentered):              0.877
# Method:                 Least Squares   F-statistic:                              1589.
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):                        0.00
# Time:                        17:38:33   Log-Likelihood:                         -13601.
# No. Observations:                1338   AIC:                                  2.721e+04
# Df Residuals:                    1332   BIC:                                  2.725e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### The presence of correlation in error terms reduces model’s accuracy.If the error terms are correlated, the estimated standard errors tend to underestimate the true standard error.
#
# #### Also, lower standard errors would cause the associated p-values to be lower than actual. This will make us incorrectly conclude a parameter to be statistically significant.
#
# #### Look for Durbin – Watson (DW) statistic in the above output. It must lie between 0 and 4. If DW = 2, implies no autocorrelation, 0 < DW < 2 implies positive autocorrelation while 2 < DW < 4 indicates negative autocorrelation.
#
# #### As we can see the DW statistic is aproximately 2 which means there is no presence of autocorrelation.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 


vif_data = pd.DataFrame() 
vif_data["feature"] = X.columns 
#### There are two major things we can notice:
  
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X.values, i) 
                          for i in range(len(X.columns))] 

print(vif_data)
# Out:
#     feature        VIF
# 0       age   7.786506
# 1       sex   8.277567
# 2       bmi  15.432813
# 3  children   1.810427
# 4    smoker   1.262349
# 5    region   5.994698

# %% [markdown]
# #### Multicollinearity phenomenon exists when the independent variables are found to be moderately or highly correlated. In a model with correlated variables, it becomes a tough task to find out which variable is actually contributing to predict the response variable.
#
# #### With presence of correlated predictors, the standard errors tend to increase. Also, when predictors are correlated, the estimated regression coefficient of a correlated variable depends on which other predictors are available in the model. If this happens, we will end up with an incorrect conclusion that a variable strongly / weakly affects target variable. Even if you drop one correlated variable from the model, its estimated regression coefficients would change.
#
# #### We can use VIF(Variance inflation factor) factor. VIF value <= 4 suggests no multicollinearity whereas a value of >= 10 implies serious multicollinearity.
#
# #### As we can see in the above output age, sex and bmi are correlated and hence multicollinearity phenomenon exits in the dataset.

# %%
pred_val = reg.fittedvalues.copy()
true_val = y.copy()
residual = true_val - pred_val

# %%
plot_lm_1 = plt.figure(figsize = (20,10))
plot_lm_1.axes[0] = sns.residplot(pred_val, data.columns[-1], data=data,
                          lowess=True,
                          scatter_kws={'alpha': 0.5},
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

plot_lm_1.axes[0].set_title('Residuals vs Fitted')
plot_lm_1.axes[0].set_xlabel('Fitted values')
plot_lm_1.axes[0].set_ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# #### This scatter plot shows the distribution of residuals (errors) vs fitted values (predicted values).It reveals various useful insights including outliers.
#
# #### There exist a pattern in this plot, we can consider it as signs of non-linearity in the data. It means that the model doesn’t capture non-linear effects.
#
# #### To overcome the issue of non-linearity, we can do a non linear transformation of predictors such as log (X), √X or X² transform the dependent variable.

# %%
plt.figure(figsize=(15,10))
plt.scatter(residual, pred_val, alpha = 0.5)
plt.show()

# %% [markdown]
# #### As we can see in the above a funnel shape is evident in the plot, we can consider it as the sign of non constant variance i.e. heteroskedasticity. Also,we can use Breusch-Pagan / Cook – Weisberg test or White general test to detect this phenomenon.
#
# #### To overcome heteroskedasticity, a possible way is to transform the response variable such as log(Y) or √Y. Also, we can use weighted least square method to tackle heteroskedasticity.

# %%
from statsmodels.graphics.gofplots import qqplot
import matplotlib as mpl

with mpl.rc_context():
    mpl.rc("figure", figsize=(20,10))
    qqplot(residual, line = 'r')

# %% [markdown]
# #### As we can see in the above qq(quantile-quantile) plot there is no normality in the distribution met and hence the model violates the normality assumption.
#
# #### If the errors are not normally distributed, non – linear transformation of the variables (response or predictors) can bring improvement in the model.
